# %% [markdown]
# <a href="https://colab.research.google.com/github/RizkyWidodo-project/EJ-EONC_Project/blob/main/Request_Travel_Time_Google_Maps_RouteAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prepare Workspace

# %%
# !pip install requests pandas folium googlemaps matplotlib

import requests
import pandas as pd
import time
from datetime import datetime, timedelta
import pytz
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# Load filtered data (make sure to upload the CSV to your Google Colab environment)
data = pd.read_csv('filename.csv', sep=';')

print("filename.csv")
print(data.columns.tolist())

# %% [markdown]
# #Travel Time Estimation Request

# %%
# Google Maps API Key (replace with your own key)
API_KEY = 'YOUR API'

# Set the departure time explicitly: Next Monday 7 AM WIB
jakarta_tz = pytz.timezone('Asia/Jakarta')
now = datetime.now(jakarta_tz)

# Calculate next Monday at 7 AM
days_until_monday = (7 - now.weekday()) % 7
# If today is Monday and it's already past 7 AM, set it for next week Monday
if days_until_monday == 0 and now.hour >= 7:
    days_until_monday = 7

next_monday_7am = now + timedelta(days=days_until_monday)
departure_time = next_monday_7am.replace(hour=7, minute=0, second=0, microsecond=0)

# Ensure departure_time is in the future relative to 'now'
# This double-check handles edge cases where the calculation might still result in a past time
if departure_time <= now:
     departure_time += timedelta(days=7)


# Format the departure time as an ISO 8601 string with timezone offset
# The API expects this format for future timestamps
departure_timestamp = departure_time.astimezone(pytz.utc).isoformat()


# Corrected and explicitly verified Field Mask
headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY,
    "X-Goog-FieldMask": "routes.duration,routes.distanceMeters"
}

# Robust API function modified to accept travel_mode
def get_travel_time_distance(origin_coords, destination_coords, departure_time_iso, travel_mode):
    url = "https://routes.googleapis.com/directions/v2:computeRoutes"

    body = {
        "origin": {"location": {"latLng": origin_coords}},
        "destination": {"location": {"latLng": destination_coords}},
        "travelMode": travel_mode
    }

    # Add traffic-awareness and departure time ONLY for DRIVE and TWO_WHEELER
    # These fields are not supported or may cause errors for WALK and BICYCLE
    if travel_mode in ["DRIVE", "TWO_WHEELER"]:
        body["routingPreference"] = "TRAFFIC_AWARE"
        # Ensure departure_time_iso is correctly formatted UTC string or includes timezone offset
        body["departureTime"] = departure_time_iso

    try:
        response = requests.post(url, headers=headers, json=body)
        response.raise_for_status()  # Raises an HTTPError for bad responses (4XX or 5XX)
        result = response.json()

        if 'routes' in result and len(result['routes']) > 0:
            route = result['routes'][0]
            duration_str = route.get('duration')
            distance_val = route.get('distanceMeters')
            travel_time_minutes = None
            if duration_str:
                try:
                    # Duration is in seconds, e.g., "3600s"
                    duration_sec = int(duration_str.replace('s', ''))
                    travel_time_minutes = duration_sec / 60
                except ValueError:
                    print(f"⚠️ Could not parse duration: {duration_str} for mode {travel_mode}")
                    travel_time_minutes = None

            if travel_time_minutes is None or distance_val is None:
                print(f"⚠️ Missing duration or distance in API response for {travel_mode}. Origin: {origin_coords}, Dest: {dest_coords}")
                return None, None
            return travel_time_minutes, distance_val
        else:
            # This case includes when result is {} (no route found)
            # print(f"ℹ️ No route found via {travel_mode} for Origin: {origin_coords}, Dest: {dest_coords}. Result: {result}")
            return None, None

    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred for {travel_mode}: {http_err} - Response: {response.text if 'response' in locals() else 'No response object'}")
        return None, None
    except requests.exceptions.RequestException as e:
        print(f"⚠️ Request failed for {travel_mode}: {e}")
        return None, None
    except ValueError as e: # Catches JSON decoding errors
        print(f"⚠️ JSON decoding failed for {travel_mode}: {e} - Response: {response.text if 'response' in locals() else 'No response object'}")
        return None, None

# --- Main loop to process data ---
results = []
travel_modes_to_try = ["DRIVE", "TWO_WHEELER", "BICYCLE", "WALK"]

print(f"Starting API calls for {len(data)} rows, trying modes: {', '.join(travel_modes_to_try)}...")

for idx, row in data.iterrows():
    print(f"Processing row {idx + 1}/{len(data)}...")

    try:
        origin_lat = row['centroids_lat']
        origin_lon = row['centroids_lng']
        dest_lat = row['HF_Latitude']
        dest_lon = row['HF_Longitude']
        cell_id = row.get('cell_id', f"MISSING_CELL_ID_IDX_{idx}")
        city = row.get('city_x', "Unknown City")
    except KeyError as e:
        print(f"⚠️ Critical column missing in row {idx}: {e}. Skipping this row.")
        results.append({
            "cell_id": f"ERROR_MISSING_COLUMN_IDX_{idx}", "city": "N/A",
            "origin_lat": None, "origin_lng": None, "dest_lat": None, "dest_lng": None,
            "travel_time_min": "Error: Missing Column Data",
            "distance_meters": "Error: Missing Column Data",
            "travel_mode": "N/A" # New column
        })
        continue

    final_travel_time = "Error: No route found for any mode"
    final_distance = "Error: No route found for any mode"
    final_mode_used = "N/A"
    found_route_for_pair = False

    if pd.isna(origin_lat) or pd.isna(origin_lon) or \
       pd.isna(dest_lat) or pd.isna(dest_lon):
        print(f"⚠️ Skipping row {idx+1} (cell_id: {cell_id}) due to missing/NaN coordinates.")
        final_travel_time, final_distance, final_mode_used = "Error: Missing/NaN Coordinates", "Error: Missing/NaN Coordinates", "N/A"
    else:
        try:
            current_origin = {"latitude": float(origin_lat), "longitude": float(origin_lon)}
            current_destination = {"latitude": float(dest_lat), "longitude": float(dest_lon)}

            for mode_attempt in travel_modes_to_try:
                # print(f"  Trying mode: {mode_attempt} for row {idx+1} (CellID: {cell_id})...")
                travel_time_minutes, distance_val = get_travel_time_distance(
                    current_origin, current_destination, departure_timestamp, mode_attempt
                )

                if travel_time_minutes is not None and distance_val is not None:
                    final_travel_time = travel_time_minutes
                    final_distance = distance_val
                    final_mode_used = mode_attempt
                    found_route_for_pair = True
                    print(f"  ✅ Route found for row {idx+1} (CellID: {cell_id}) with {mode_attempt}: {final_travel_time:.2f} min, {final_distance} m")
                    break # Exit loop once a route is found for this pair

            if not found_route_for_pair:
                print(f"  ⚠️ No route found for any mode for row {idx+1} (CellID: {cell_id}).")
                # Values already set to "Error: No route found for any mode"

        except ValueError: # Error converting coordinates to float
            print(f"⚠️ Skipping row {idx+1} (cell_id: {cell_id}) due to invalid coordinate format.")
            final_travel_time, final_distance, final_mode_used = "Error: Invalid Coordinate Format", "Error: Invalid Coordinate Format", "N/A"

    results.append({
        "cell_id": cell_id,
        "city": city,
        "origin_lat": origin_lat,
        "origin_lng": origin_lon,
        "dest_lat": dest_lat,
        "dest_lng": dest_lon,
        "travel_time_min": final_travel_time,
        "distance_meters": final_distance,
        "travel_mode": final_mode_used
    })

    time.sleep(0.1) # Be respectful to the API rate limits

print("\nAPI calls completed.")
# Out:
# Starting API calls for 124 rows, trying modes: DRIVE, TWO_WHEELER, BICYCLE, WALK...
# Processing row 1/124...
#   ⚠️ No route found for any mode for row 1 (CellID: 150558.0).
# Processing row 2/124...
#   ⚠️ No route found for any mode for row 2 (CellID: 150974.0).
# Processing row 3/124...
#   ⚠️ No route found for any mode for row 3 (CellID: 151805.0).
# Processing row 4/124...
#   ⚠️ No route found for any mode for row 4 (CellID: 152218.0).
# Processing row 5/124...
#   ⚠️ No route found for any mode for row 5 (CellID: 152634.0).
# Processing row 6/124...
#   ⚠️ No route found for any mode for row 6 (CellID: 152635.0).
# Processing row 7/124...
#   ⚠️ No route found for any mode for row 7 (CellID: 152636.0).
# Processing row 8/124...
#   ⚠️ No route found for any mode for row 8 (CellID: 152637.0).
# Processing row 9/124...
#   ⚠️ No route found for any mode for row 9 (CellID: 153050.0).
# Processing row 10/124...
#   ⚠️ No route found for any mode for row 10 (CellID: 153052.0).
# Processing row 11/124...
#   ⚠️ No route found for any mode for row 11 (CellID: 90498.0).
# Processing row 12/124...
#   ⚠️ No route found for any mode for row 12 (CellID: 117963.0).
# Processing row 13/124...
#   ⚠️ No route found for any mode for row 13 (CellID: 118380.0).
# Processing row 14/124...
#   ⚠️ No route found for any mode for row 14 (CellID: 118382.0).
# Processing row 15/124...
#   ⚠️ No route found for any mode for row 15 (CellID: 118797.0).
# Processing row 16/124...
#   ⚠️ No route found for any mode for row 16 (CellID: 118798.0).
# Processing row 17/124...
#   ⚠️ No route found for any mode for row 17 (CellID: 142164.0).
# Processing row 18/124...
#   ⚠️ No route found for any mode for row 18 (CellID: 102603.0).
# Processing row 19/124...
#   ⚠️ No route found for any mode for row 19 (CellID: 103018.0).
# Processing row 20/124...
#   ⚠️ No route found for any mode for row 20 (CellID: 174222.0).
# Processing row 21/124...
#   ⚠️ No route found for any mode for row 21 (CellID: 174641.0).
# Processing row 22/124...
#   ⚠️ No route found for any mode for row 22 (CellID: 175058.0).
# Processing row 23/124...
#   ⚠️ No route found for any mode for row 23 (CellID: 175473.0).
# Processing row 24/124...
#   ⚠️ No route found for any mode for row 24 (CellID: 175474.0).
# Processing row 25/124...
#   ⚠️ No route found for any mode for row 25 (CellID: 176304.0).
# Processing row 26/124...
#   ⚠️ No route found for any mode for row 26 (CellID: 65676.0).
# Processing row 27/124...
#   ⚠️ No route found for any mode for row 27 (CellID: 163853.0).
# Processing row 28/124...
#   ⚠️ No route found for any mode for row 28 (CellID: 118381.0).
# Processing row 29/124...
#   ⚠️ No route found for any mode for row 29 (CellID: 118799.0).
# Processing row 30/124...
#   ⚠️ No route found for any mode for row 30 (CellID: 159690.0).
# Processing row 31/124...
#   ⚠️ No route found for any mode for row 31 (CellID: 160106.0).
# Processing row 32/124...
#   ⚠️ No route found for any mode for row 32 (CellID: 160107.0).
# Processing row 33/124...
#   ⚠️ No route found for any mode for row 33 (CellID: 160522.0).
# Processing row 34/124...
#   ⚠️ No route found for any mode for row 34 (CellID: 90571.0).
# Processing row 35/124...
#   ⚠️ No route found for any mode for row 35 (CellID: 122216.0).
# Processing row 36/124...
#   ⚠️ No route found for any mode for row 36 (CellID: 104279.0).
# Processing row 37/124...
#   ⚠️ No route found for any mode for row 37 (CellID: 104694.0).
# Processing row 38/124...
#   ⚠️ No route found for any mode for row 38 (CellID: 239405.0).
# Processing row 39/124...
#   ⚠️ No route found for any mode for row 39 (CellID: 239406.0).
# Processing row 40/124...
#   ⚠️ No route found for any mode for row 40 (CellID: 241902.0).
# Processing row 41/124...
#   ⚠️ No route found for any mode for row 41 (CellID: 241903.0).
# Processing row 42/124...
#   ⚠️ No route found for any mode for row 42 (CellID: 242318.0).
# Processing row 43/124...
#   ⚠️ No route found for any mode for row 43 (CellID: 242319.0).
# Processing row 44/124...
#   ⚠️ No route found for any mode for row 44 (CellID: 242320.0).
# Processing row 45/124...
#   ⚠️ No route found for any mode for row 45 (CellID: 242734.0).
# Processing row 46/124...
#   ⚠️ No route found for any mode for row 46 (CellID: 242735.0).
# Processing row 47/124...
#   ⚠️ No route found for any mode for row 47 (CellID: 238581.0).
# Processing row 48/124...
#   ⚠️ No route found for any mode for row 48 (CellID: 238582.0).
# Processing row 49/124...
#   ⚠️ No route found for any mode for row 49 (CellID: 238997.0).
# Processing row 50/124...
#   ⚠️ No route found for any mode for row 50 (CellID: 238998.0).
# Processing row 51/124...
#   ⚠️ No route found for any mode for row 51 (CellID: 239413.0).
# Processing row 52/124...
#   ⚠️ No route found for any mode for row 52 (CellID: 232343.0).
# Processing row 53/124...
#   ⚠️ No route found for any mode for row 53 (CellID: 232759.0).
# Processing row 54/124...
#   ⚠️ No route found for any mode for row 54 (CellID: 233176.0).
# Processing row 55/124...
#   ⚠️ No route found for any mode for row 55 (CellID: 233177.0).
# Processing row 56/124...
#   ⚠️ No route found for any mode for row 56 (CellID: 233591.0).
# Processing row 57/124...
#   ⚠️ No route found for any mode for row 57 (CellID: 233592.0).
# Processing row 58/124...
#   ⚠️ No route found for any mode for row 58 (CellID: 234425.0).
# Processing row 59/124...
#   ⚠️ No route found for any mode for row 59 (CellID: 234842.0).
# Processing row 60/124...
#   ⚠️ No route found for any mode for row 60 (CellID: 240656.0).
# Processing row 61/124...
#   ⚠️ No route found for any mode for row 61 (CellID: 241072.0).
# Processing row 62/124...
#   ⚠️ No route found for any mode for row 62 (CellID: 241486.0).
# Processing row 63/124...
#   ⚠️ No route found for any mode for row 63 (CellID: 241488.0).
# Processing row 64/124...
#   ⚠️ No route found for any mode for row 64 (CellID: 243151.0).
# Processing row 65/124...
#   ⚠️ No route found for any mode for row 65 (CellID: 243152.0).
# Processing row 66/124...
#   ⚠️ No route found for any mode for row 66 (CellID: 168438.0).
# Processing row 67/124...
#   ⚠️ No route found for any mode for row 67 (CellID: 168854.0).
# Processing row 68/124...
#   ⚠️ No route found for any mode for row 68 (CellID: 65675.0).
# Processing row 69/124...
#   ⚠️ No route found for any mode for row 69 (CellID: 198668.0).
# Processing row 70/124...
#   ⚠️ No route found for any mode for row 70 (CellID: 230664.0).
# Processing row 71/124...
#   ⚠️ No route found for any mode for row 71 (CellID: 230665.0).
# Processing row 72/124...
#   ⚠️ No route found for any mode for row 72 (CellID: 232344.0).
# Processing row 73/124...
#   ✅ Route found for row 73 (CellID: 80509.0) with DRIVE: 27.90 min, 11658 m
# Processing row 74/124...
#   ⚠️ No route found for any mode for row 74 (CellID: 198253.0).
# Processing row 75/124...
#   ✅ Route found for row 75 (CellID: 80508.0) with DRIVE: 17.05 min, 6728 m
# Processing row 76/124...
#   ✅ Route found for row 76 (CellID: 98861.0) with DRIVE: 16.15 min, 4982 m
# Processing row 77/124...
#   ✅ Route found for row 77 (CellID: 99278.0) with DRIVE: 20.52 min, 6682 m
# Processing row 78/124...
#   ✅ Route found for row 78 (CellID: 99693.0) with DRIVE: 22.50 min, 7077 m
# Processing row 79/124...
#   ✅ Route found for row 79 (CellID: 99694.0) with DRIVE: 24.82 min, 8762 m
# Processing row 80/124...
#   ⚠️ No route found for any mode for row 80 (CellID: 100110.0).
# Processing row 81/124...
#   ✅ Route found for row 81 (CellID: 52776.0) with DRIVE: 27.68 min, 10401 m
# Processing row 82/124...
#   ✅ Route found for row 82 (CellID: 53192.0) with DRIVE: 24.60 min, 9289 m
# Processing row 83/124...
#   ✅ Route found for row 83 (CellID: 53609.0) with DRIVE: 38.87 min, 13247 m
# Processing row 84/124...
#   ✅ Route found for row 84 (CellID: 51894.0) with DRIVE: 25.50 min, 12685 m
# Processing row 85/124...
#   ✅ Route found for row 85 (CellID: 81759.0) with DRIVE: 34.97 min, 16897 m
# Processing row 86/124...
#   ✅ Route found for row 86 (CellID: 82174.0) with DRIVE: 34.97 min, 16897 m
# Processing row 87/124...
#   ✅ Route found for row 87 (CellID: 78848.0) with DRIVE: 19.97 min, 10385 m
# Processing row 88/124...
#   ✅ Route found for row 88 (CellID: 80927.0) with DRIVE: 32.32 min, 15661 m
# Processing row 89/124...
#   ✅ Route found for row 89 (CellID: 81343.0) with DRIVE: 24.00 min, 9121 m
# Processing row 90/124...
#   ✅ Route found for row 90 (CellID: 82173.0) with DRIVE: 15.93 min, 7712 m
# Processing row 91/124...
#   ✅ Route found for row 91 (CellID: 16095.0) with WALK: 545.28 min, 35400 m
# Processing row 92/124...
#   ✅ Route found for row 92 (CellID: 52358.0) with DRIVE: 25.98 min, 9610 m
# Processing row 93/124...
#   ✅ Route found for row 93 (CellID: 52775.0) with DRIVE: 27.68 min, 10401 m
# Processing row 94/124...
#   ✅ Route found for row 94 (CellID: 80929.0) with DRIVE: 16.22 min, 6857 m
# Processing row 95/124...
#   ✅ Route found for row 95 (CellID: 81344.0) with DRIVE: 19.60 min, 7759 m
# Processing row 96/124...
#   ✅ Route found for row 96 (CellID: 16096.0) with WALK: 512.27 min, 33543 m
# Processing row 97/124...
#   ✅ Route found for row 97 (CellID: 88072.0) with DRIVE: 13.00 min, 5775 m
# Processing row 98/124...
#   ✅ Route found for row 98 (CellID: 99277.0) with DRIVE: 19.32 min, 6400 m
# Processing row 99/124...
#   ✅ Route found for row 99 (CellID: 99692.0) with DRIVE: 40.92 min, 16116 m
# Processing row 100/124...
#   ✅ Route found for row 100 (CellID: 78847.0) with DRIVE: 27.42 min, 11434 m
# Processing row 101/124...
#   ✅ Route found for row 101 (CellID: 241079.0) with DRIVE: 64.85 min, 25007 m
# Processing row 102/124...
#   ✅ Route found for row 102 (CellID: 16098.0) with DRIVE: 20.88 min, 10899 m
# Processing row 103/124...
#   ✅ Route found for row 103 (CellID: 81341.0) with DRIVE: 17.53 min, 9196 m
# Processing row 104/124...
#   ✅ Route found for row 104 (CellID: 81342.0) with DRIVE: 21.48 min, 10451 m
# Processing row 105/124...
#   ✅ Route found for row 105 (CellID: 81758.0) with DRIVE: 21.02 min, 9991 m
# Processing row 106/124...
#   ✅ Route found for row 106 (CellID: 189587.0) with DRIVE: 80.05 min, 43412 m
# Processing row 107/124...
#   ✅ Route found for row 107 (CellID: 109729.0) with DRIVE: 53.10 min, 24680 m
# Processing row 108/124...
#   ✅ Route found for row 108 (CellID: 101454.0) with DRIVE: 57.30 min, 23175 m
# Processing row 109/124...
#   ✅ Route found for row 109 (CellID: 94756.0) with DRIVE: 20.03 min, 6578 m
# Processing row 110/124...
#   ✅ Route found for row 110 (CellID: 83939.0) with DRIVE: 104.07 min, 50517 m
# Processing row 111/124...
#   ✅ Route found for row 111 (CellID: 84352.0) with DRIVE: 22.87 min, 10352 m
# Processing row 112/124...
#   ✅ Route found for row 112 (CellID: 84338.0) with DRIVE: 20.73 min, 7415 m
# Processing row 113/124...
#   ✅ Route found for row 113 (CellID: 80513.0) with DRIVE: 17.77 min, 6925 m
# Processing row 114/124...
#   ✅ Route found for row 114 (CellID: 80514.0) with DRIVE: 17.28 min, 6886 m
# Processing row 115/124...
#   ✅ Route found for row 115 (CellID: 80515.0) with DRIVE: 11.15 min, 4325 m
# Processing row 116/124...
#   ✅ Route found for row 116 (CellID: 80930.0) with DRIVE: 12.70 min, 5531 m
# Processing row 117/124...
#   ✅ Route found for row 117 (CellID: 80931.0) with DRIVE: 10.90 min, 4538 m
# Processing row 118/124...
#   ✅ Route found for row 118 (CellID: 80932.0) with DRIVE: 9.95 min, 3954 m
# Processing row 119/124...
#   ✅ Route found for row 119 (CellID: 81763.0) with DRIVE: 12.82 min, 5446 m
# Processing row 120/124...
#   ✅ Route found for row 120 (CellID: 81345.0) with DRIVE: 15.15 min, 6579 m
# Processing row 121/124...
#   ✅ Route found for row 121 (CellID: 81347.0) with DRIVE: 12.07 min, 4684 m
# Processing row 122/124...
#   ✅ Route found for row 122 (CellID: 80099.0) with DRIVE: 13.40 min, 5151 m
# Processing row 123/124...
#   ✅ Route found for row 123 (CellID: 80100.0) with DRIVE: 12.97 min, 5337 m
# Processing row 124/124...
#   ✅ Route found for row 124 (CellID: 189586.0) with DRIVE: 53.18 min, 19625 m
#
# API calls completed.

# %% [markdown]
# #Display and Save the Result

# %%
if results:
    results_df = pd.DataFrame(results)
    print("\nFirst 5 results:")
    print(results_df.head())
    try:
      results_df.to_csv('travel_times_output_multi_mode.csv', index=False, encoding='utf-8')
      print("\nResults saved to 'travel_times_output_multi_mode.csv'")
    except Exception as e:
      print(f"Error saving results to CSV: {e}")
else:
    print("No results were processed or generated.")
# Out:
# First 5 results:
#     cell_id    city  origin_lat  origin_lng  dest_lat    dest_lng  \
# 0  150558.0  Jember   -8.480965  113.714199 -8.348291  113.608239
# 1  150974.0  Jember   -8.476465  113.721993 -8.348291  113.608239
# 2  151805.0  Jember   -8.467465  113.737582 -8.348291  113.608239
# 3  152218.0  Jember   -8.444965  113.745376 -8.348291  113.608239
# 4  152634.0  Jember   -8.440465  113.753170 -8.348291  113.608239
#
#                       travel_time_min                     distance_meters  \
# 0  Error: No route found for any mode  Error: No route found for any mode
# 1  Error: No route found for any mode  Error: No route found for any mode
# 2  Error: No route found for any mode  Error: No route found for any mode
# 3  Error: No route found for any mode  Error: No route found for any mode
# 4  Error: No route found for any mode  Error: No route found for any mode
#
#   travel_mode
# 0         N/A
# 1         N/A
# 2         N/A
# 3         N/A
# 4         N/A
#
# Results saved to 'travel_times_output_multi_mode.csv'
